# %% [markdown]
# # Brightness debug notebook
#
# Run the setup cell first, then run the extraction cell once. Each condition cell plots the original images above the per-cell brightness histogram for the markers in the same order as the heatmap.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "macrophage_analysis").exists():
    raise RuntimeError("Run this notebook from the repository root or notebooks/ directory.")
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import macrophage_analysis as ma

debug_donors = list(ma.DEFAULT_DONORS)
debug_conditions = list(ma.DEFAULT_CONDITIONS)
debug_antibody_order = list(ma.DEFAULT_ANTIBODY_ORDER)

debug_donors, debug_conditions, debug_antibody_order
# Out:
# (['D45', 'D47'],
#  ['M0',
#   'B68KCP2',
#   'B75palmFP1',
#   'M130227Ni',
#   'M130429Np',
#   'T12CMNepiP4',
#   'T8CMNdermP6'],
#  ['CD40', 'CD86', 'iNOS', 'CD200R', 'CD206'])

# %% [markdown]
# Run this once to calculate the per-image brightness values. The condition cells below reuse `debug_results` and only reload the original images for display.

# %%
debug_results = ma.extract_single_cell_fluorescence(
    donors=debug_donors,
    conditions=debug_conditions,
    antibody_order=debug_antibody_order,
)
# Out:
# Analyzing CD40...
# Found model '2D_versatile_fluo' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.479071, nms_thresh=0.3.
# ...
# 100%|██████████| 4/4 [00:00<00:00, 14.87it/s]
# Analyzing CD86...
# ...
# 100%|██████████| 4/4 [00:00<00:00, 14.70it/s]
# Analyzing iNOS...
# ...
# 100%|██████████| 4/4 [00:00<00:00, 15.26it/s]
# Analyzing CD200R...
# ...
# 100%|██████████| 4/4 [00:00<00:00, 15.13it/s]
# Analyzing CD206...
# ...
# 100%|██████████| 4/4 [00:00<00:00, 14.35it/s]
# Finished analyzing 70 donor / treatment / antibody combinations.

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "M0",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "B68KCP2",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "B75palmFP1",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "M130227Ni",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "M130429Np",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "T12CMNepiP4",
    antibody_order=debug_antibody_order,
)

# %%
ma.plot_condition_brightness_debug(
    debug_results,
    "T8CMNdermP6",
    antibody_order=debug_antibody_order,
)
